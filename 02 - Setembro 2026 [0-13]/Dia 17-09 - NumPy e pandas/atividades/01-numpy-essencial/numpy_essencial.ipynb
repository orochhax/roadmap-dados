# %% [markdown]
# ## Começo guiado
#
# **Dados de partida:** `dados/incidentes.csv`, `dados/clientes_telecom.csv`, `dados/pedidos.csv` e `dados/metas_cidades.csv`.
#
# Não crie uma base nova. Use os valores, arquivos ou tabelas já indicados e resolva uma atividade por vez. Execute a célula e confira o número, a tabela ou o gráfico antes de seguir.

# %% [markdown]
# # NumPy essencial
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. Crie `numpy_essencial.ipynb` e um array com durações `[15,30,45,60,90,120,180,240]`; calcule média, mediana, desvio, mínimo, máximo e percentis 25/75.

# %% [markdown]
# ## Atividade 2
#
# 2. Crie uma matriz 4x3 representando quatro cidades e três métricas; selecione linhas, colunas e fatias usando indexação.

# %% [markdown]
# ## Atividade 3
#
# 3. Aplique uma operação vetorizada aos valores acima de um limite e compare o resultado com um laço, sem medir desempenho ainda.

# %% [markdown]
# ## Prática obrigatória 1
#
# 4. Normalize uma coluna pelo método min-max e confirme manualmente os valores mínimo e máximo produzidos.

# %% [markdown]
# ## Prática obrigatória 2
#
# 5. Teste `NaN`, array vazio e divisão por desvio zero; escreva como trataria cada caso.
