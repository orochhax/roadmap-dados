# %% [markdown]
# ## Começo guiado
#
# **Dados de partida:** `dados/incidentes.csv`, `dados/clientes_telecom.csv`, `dados/pedidos.csv` e `dados/metas_cidades.csv`.
#
# Não crie uma base nova. Use os valores, arquivos ou tabelas já indicados e resolva uma atividade por vez. Execute a célula e confira o número, a tabela ou o gráfico antes de seguir.

# %% [markdown]
# # pandas: Series e DataFrame
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. Crie `pandas_basico.ipynb` e monte um DataFrame de 12 incidentes a partir de um dicionário.

# %% [markdown]
# ## Atividade 2
#
# 2. Inspecione `shape`, `columns`, `dtypes`, `head`, `tail`, `info` e `describe`; escreva uma interpretação de cada saída.

# %% [markdown]
# ## Atividade 3
#
# 3. Selecione colunas com `[]`, linhas com `loc` e posições com `iloc`; crie cinco filtros combinando cidade, severidade e duração.

# %% [markdown]
# ## Prática obrigatória 1
#
# 4. Crie colunas `duracao_horas` e `impacto = duracao_min * clientes_afetados` sem usar laço.

# %% [markdown]
# ## Prática obrigatória 2
#
# 5. Ordene pelos maiores impactos, selecione os três principais e confirme manualmente os cálculos.
#
# 6. Em uma cópia, substitua uma duração por valor ausente e registre o efeito em `dtypes`, `describe()` e no cálculo de impacto.
