# %% [markdown]
# # EDA prática
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. Escreva três perguntas de negócio sobre churn antes de iniciar a análise.

# %% [markdown]
# ## Atividade 2
#
# 2. Faça inspeção estrutural, qualidade, estatísticas e distribuição do alvo; não gere gráficos antes das perguntas.

# %% [markdown]
# ## Atividade 3
#
# 3. Crie três análises segmentadas diretamente ligadas às perguntas escolhidas.

# %% [markdown]
# ## Atividade 4
#
# 4. Produza dois gráficos e um resumo com três achados, uma limitação e uma próxima análise.

# %% [markdown]
# ## Prática obrigatória
#
# 5. Escreva uma recomendação limitada a uma evidência numérica da análise.
#
# 6. Compare churn, NPS mediano e chamados médios dos clientes com menos de seis meses com a base completa.
#
# 7. Em uma cópia, deixe o NPS ausente em cinco linhas e registre quais tabelas ou gráficos mudam antes de escolher tratamento.
