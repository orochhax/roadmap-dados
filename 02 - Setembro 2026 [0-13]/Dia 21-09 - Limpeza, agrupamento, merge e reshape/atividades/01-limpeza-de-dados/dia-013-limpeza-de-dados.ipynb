# %% [markdown]
# ## Começo guiado
#
# **Dados de partida:** `dados/incidentes.csv`, `dados/clientes_telecom.csv`, `dados/pedidos.csv` e `dados/metas_cidades.csv`.
#
# Não crie uma base nova. Use os valores, arquivos ou tabelas já indicados e resolva uma atividade por vez. Execute a célula e confira o número, a tabela ou o gráfico antes de seguir.

# %% [markdown]
# # Limpeza de dados
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. Use uma base com ausentes, duplicados, categorias inconsistentes (`Eunapolis`, `Eunápolis`, `EUNÁPOLIS`) e valores extremos.

# %% [markdown]
# ## Atividade 2
#
# 2. Produza um relatório inicial com quantidade e percentual de ausentes, duplicados e valores inválidos por coluna.

# %% [markdown]
# ## Atividade 3
#
# 3. Padronize textos, converta datas e tipos, trate duplicados com regra explícita e escolha uma estratégia para cada ausente.

# %% [markdown]
# ## Prática obrigatória 1
#
# 4. Teste uma categoria com espaços e capitalização diferente usando a mesma função de padronização.

# %% [markdown]
# ## Prática obrigatória 2
#
# 5. Salve `dados_limpos.csv` e `relatorio_limpeza.md` com antes/depois, decisões e riscos de distorção.
#
# 6. Inclua uma duração de 9999 minutos em uma cópia, trate-a como caso suspeito e preserve a linha até escrever uma justificativa.
