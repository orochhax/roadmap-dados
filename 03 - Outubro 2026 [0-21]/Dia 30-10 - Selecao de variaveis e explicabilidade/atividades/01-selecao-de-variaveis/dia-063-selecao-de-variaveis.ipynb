# %% [markdown]
# ## Começo guiado
#
# **Dados de partida:** `dados/clientes_telecom.csv` e `dados/pedidos.csv`.
#
# Não crie uma base nova. Use os valores, arquivos ou tabelas já indicados e resolva uma atividade por vez. Execute a célula e confira o número, a tabela ou o gráfico antes de seguir.

# %% [markdown]
# # Seleção de variáveis
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. Remova colunas constantes, quase constantes e duplicadas.

# %% [markdown]
# ## Atividade 2
#
# 2. Calcule correlação entre numéricas e identifique grupos redundantes.

# %% [markdown]
# ## Atividade 3
#
# 3. Compare seleção univariada, importância de modelo e RFE em subconjunto pequeno.

# %% [markdown]
# ## Prática obrigatória 1
#
# 4. Treine modelo com todas as features e com seleção; compare métrica e estabilidade.

# %% [markdown]
# ## Prática obrigatória 2
#
# 5. Documente por que feature selecionada não implica causalidade.

# %% [markdown]
# ## Prática obrigatória — adaptação 1
#
# 1. Compare remoção de correlações acima de 0,90 e 0,75 e registre quantidade de features e métrica.

# %% [markdown]
# ## Prática obrigatória — adaptação 2
#
# 2. Adicione uma cópia exata de uma coluna, faça a detecção removê-la e confirme que a original permanece.
