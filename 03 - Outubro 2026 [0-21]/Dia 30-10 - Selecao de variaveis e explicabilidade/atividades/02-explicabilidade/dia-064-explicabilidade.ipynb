# %% [markdown]
# ## Começo guiado
#
# **Dados de partida:** `dados/clientes_telecom.csv` e `dados/pedidos.csv`.
#
# Não crie uma base nova. Use os valores, arquivos ou tabelas já indicados e resolva uma atividade por vez. Execute a célula e confira o número, a tabela ou o gráfico antes de seguir.

# %% [markdown]
# # Explicabilidade
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. Escolha 10 previsões individuais, incluindo acertos e erros, e explique fatores principais.

# %% [markdown]
# ## Atividade 2
#
# 2. Use coeficientes, permutation importance e SHAP se disponível; compare explicações globais e locais.

# %% [markdown]
# ## Atividade 3
#
# 3. Teste explicações em dois segmentos demográficos ou operacionais.

# %% [markdown]
# ## Prática obrigatória 1
#
# 4. Identifique uma explicação plausível porém enganosa causada por correlação.

# %% [markdown]
# ## Prática obrigatória 2
#
# 5. Crie relatório para público não técnico com três cuidados ao interpretar importância.

# %% [markdown]
# ## Prática obrigatória — adaptação 1
#
# 1. Explique uma previsão correta de churn alto e uma incorreta de churn baixo usando o mesmo método local.

# %% [markdown]
# ## Prática obrigatória — adaptação 2
#
# 2. Remova a feature mais correlacionada com a principal e gere novamente a explicação para observar estabilidade.
