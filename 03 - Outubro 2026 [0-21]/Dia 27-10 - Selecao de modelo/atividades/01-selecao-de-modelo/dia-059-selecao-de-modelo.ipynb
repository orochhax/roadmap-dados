# %% [markdown]
# ## Começo guiado
#
# **Dados de partida:** `dados/clientes_telecom.csv` e `dados/pedidos.csv`.
#
# Não crie uma base nova. Use os valores, arquivos ou tabelas já indicados e resolva uma atividade por vez. Execute a célula e confira o número, a tabela ou o gráfico antes de seguir.

# %% [markdown]
# # Seleção de modelo
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. Crie uma tabela única com os candidatos fornecidos nesta sessão ou com modelos fallback, usando a mesma validação e as mesmas métricas.

# %% [markdown]
# ## Atividade 2
#
# 2. Defina critérios de escolha antes de olhar o vencedor: custo, recall, calibração, tempo, explicabilidade.

# %% [markdown]
# ## Atividade 3
#
# 3. Use teste ou bootstrap para verificar estabilidade da diferença entre os dois melhores.

# %% [markdown]
# ## Prática obrigatória 1
#
# 4. Escolha modelo campeão e um challenger.

# %% [markdown]
# ## Prática obrigatória 2
#
# 5. Escreva decisão com trade-offs, não apenas ranking.

# %% [markdown]
# ## Prática obrigatória — adaptação 1
#
# 1. Refaça o ranking dando peso dobrado ao custo e depois peso dobrado à explicabilidade; registre se campeão e challenger mudam.

# %% [markdown]
# ## Prática obrigatória — adaptação 2
#
# 2. Use bootstrap com seed 42 para comparar os dois melhores em 200 reamostragens do conjunto de validação.
