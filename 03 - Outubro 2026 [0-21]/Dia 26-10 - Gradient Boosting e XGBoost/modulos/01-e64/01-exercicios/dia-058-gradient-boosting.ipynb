# %% [markdown]
# ## Começo guiado
#
# **Dados de partida:** `dados/clientes_telecom.csv` e `dados/pedidos.csv`.
#
# Não crie uma base nova. Use os valores, arquivos ou tabelas já indicados e resolva uma atividade por vez. Execute a célula e confira o número, a tabela ou o gráfico antes de seguir.

# %% [markdown]
# # Gradient Boosting
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. [ ] Treine `GradientBoostingClassifier` como referência e `XGBClassifier` usando exatamente o mesmo split e pré-processamento. Registre a versão do XGBoost.

# %% [markdown]
# ## Atividade 2
#
# 2. [ ] No XGBoost, compare uma grade pequena de `learning_rate`, `n_estimators` e `max_depth`. Registre métrica, tempo de treino e tempo de inferência em `resultados_boosting.csv`.

# %% [markdown]
# ## Atividade 3
#
# 3. [ ] Compare treino e validação para identificar overfitting. Salve em `versoes.json` as bibliotecas, versões, seed, parâmetros finais e comando de execução.

# %% [markdown]
# ## Prática obrigatória 1
#
# 4. [ ] Analise importância e erros por segmento.

# %% [markdown]
# ## Prática obrigatória 2
#
# 5. [ ] Documente por que boosting pode ganhar em dados tabulares e quais riscos de tuning existem.

# %% [markdown]
# ## Prática obrigatória — adaptação 1
#
# 1. [ ] Compare learning_rate 0,05 com 0,20 usando 100 e 300 estimadores no mesmo split.

# %% [markdown]
# ## Prática obrigatória — adaptação 2
#
# 2. [ ] Calcule a métrica separadamente para clientes com até 6 meses e acima de 24 meses de relacionamento.
