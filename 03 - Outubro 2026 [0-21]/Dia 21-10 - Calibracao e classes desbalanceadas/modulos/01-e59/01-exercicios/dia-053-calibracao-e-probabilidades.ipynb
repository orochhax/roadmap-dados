# %% [markdown]
# ## Começo guiado
#
# **Dados de partida:** `dados/clientes_telecom.csv` e `dados/pedidos.csv`.
#
# Não crie uma base nova. Use os valores, arquivos ou tabelas já indicados e resolva uma atividade por vez. Execute a célula e confira o número, a tabela ou o gráfico antes de seguir.

# %% [markdown]
# # Calibração e probabilidades
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. [ ] Crie gráfico de calibração e calcule Brier Score para a regressão logística e para uma cópia de suas probabilidades elevada ao quadrado.

# %% [markdown]
# ## Atividade 2
#
# 2. [ ] Agrupe probabilidades em decis e compare previsão média com frequência real.

# %% [markdown]
# ## Atividade 3
#
# 3. [ ] Aplique `CalibratedClassifierCV` com métodos sigmoid e isotonic.

# %% [markdown]
# ## Prática obrigatória 1
#
# 4. [ ] Compare discriminação e calibração antes/depois.

# %% [markdown]
# ## Prática obrigatória 2
#
# 5. [ ] Explique por que uma probabilidade mal calibrada prejudica política de crédito ou retenção.

# %% [markdown]
# ## Prática obrigatória — adaptação 1
#
# 1. [ ] Crie probabilidades artificialmente confiantes elevando-as ao quadrado e compare Brier Score e curva de calibração.

# %% [markdown]
# ## Prática obrigatória — adaptação 2
#
# 2. [ ] Calcule calibração separadamente para planos Básico 100 e Família 500 e registre o tamanho de cada grupo.
