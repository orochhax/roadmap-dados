# %% [markdown]
# ## Começo guiado
#
# **Dados de partida:** `dados/clientes_telecom.csv` e `dados/pedidos.csv`.
#
# Não crie uma base nova. Use os valores, arquivos ou tabelas já indicados e resolva uma atividade por vez. Execute a célula e confira o número, a tabela ou o gráfico antes de seguir.

# %% [markdown]
# # Classes desbalanceadas
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. [ ] Meça a proporção de classes e crie baseline que sempre prevê a maioria.

# %% [markdown]
# ## Atividade 2
#
# 2. [ ] Compare `class_weight='balanced'`, undersampling e oversampling apenas no treino.

# %% [markdown]
# ## Atividade 3
#
# 3. [ ] Evite aplicar reamostragem antes do split; demonstre como isso vaza informação.

# %% [markdown]
# ## Prática obrigatória 1
#
# 4. [ ] Avalie PR-AUC, recall da minoria, precision e custo.

# %% [markdown]
# ## Prática obrigatória 2
#
# 5. [ ] Escolha abordagem final e registre impactos colaterais.

# %% [markdown]
# ## Prática obrigatória — adaptação 1
#
# 1. [ ] Crie uma amostra com apenas 5% de churn e compare accuracy e PR-AUC com a base original.

# %% [markdown]
# ## Prática obrigatória — adaptação 2
#
# 2. [ ] Aplique oversampling somente no treino e confirme que a proporção do conjunto de validação permanece inalterada.
