# %% [markdown]
# ## Começo guiado
#
# **Dados de partida:** `dados/clientes_telecom.csv` e `dados/pedidos.csv`.
#
# Não crie uma base nova. Use os valores, arquivos ou tabelas já indicados e resolva uma atividade por vez. Execute a célula e confira o número, a tabela ou o gráfico antes de seguir.

# %% [markdown]
# # Validação cruzada e tuning
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. [ ] Compare KFold, StratifiedKFold e validação temporal em um exemplo apropriado.

# %% [markdown]
# ## Atividade 2
#
# 2. [ ] Execute cross-validation com cinco folds e registre média e desvio das métricas.

# %% [markdown]
# ## Atividade 3
#
# 3. [ ] Faça `RandomizedSearchCV` com espaço pequeno e limite de tempo.

# %% [markdown]
# ## Prática obrigatória 1
#
# 4. [ ] Separe conjunto de teste final e não o use durante tuning.

# %% [markdown]
# ## Prática obrigatória 2
#
# 5. [ ] Compare melhor configuração com padrão e avalie se ganho compensa complexidade.

# %% [markdown]
# ## Prática obrigatória — adaptação 1
#
# 1. [ ] Compare StratifiedKFold com 3 e 5 folds usando a mesma pipeline e registre média, desvio e tempo.

# %% [markdown]
# ## Prática obrigatória — adaptação 2
#
# 2. [ ] Confirme no código que o conjunto de teste final não aparece em fit, busca de parâmetros ou escolha da configuração.
