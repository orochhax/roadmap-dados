# %% [markdown]
# ## Começo guiado
#
# **Dados de partida:** `dados/clientes_telecom.csv`, `dados/incidentes.csv` e dados sintéticos gerados no notebook com seed 42.
#
# Não crie uma base nova. Use os valores, arquivos ou tabelas já indicados e resolva uma atividade por vez. Execute a célula e confira o número, a tabela ou o gráfico antes de seguir.

# %% [markdown]
# # Teste A/B
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. [ ] Defina experimento A/B de uma oferta de retenção: unidade, população, métrica primária, guardrails, duração e critério de parada.

# %% [markdown]
# ## Atividade 2
#
# 2. [ ] Gere dados sintéticos de 2.000 clientes por grupo com taxas 10% e 11,5%; calcule diferença, IC e teste.

# %% [markdown]
# ## Atividade 3
#
# 3. [ ] Escreva uma decisão entre lançar, repetir ou abandonar, citando efeito, incerteza e risco.

# %% [markdown]
# ## Prática obrigatória 1
#
# 4. [ ] Calcule o tamanho de amostra para efeitos mínimos de 1,5 e 0,5 ponto percentual e explique por que o segundo exige mais observações.

# %% [markdown]
# ## Prática obrigatória 2
#
# 5. [ ] Execute a simulação de peeking em 30 verificações diárias e conte quantas vezes a regra pararia antes da amostra planejada.
