# %% [markdown]
# ## Começo guiado
#
# **Dados de partida:** `dados/clientes_telecom.csv` e `dados/pedidos.csv`.
#
# Não crie uma base nova. Use os valores, arquivos ou tabelas já indicados e resolva uma atividade por vez. Execute a célula e confira o número, a tabela ou o gráfico antes de seguir.

# %% [markdown]
# # Pré-processamento com Pipeline
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. Identifique colunas numéricas e categóricas e faça um primeiro `fit/predict` guiado com `DummyClassifier`.

# %% [markdown]
# ## Atividade 2
#
# 2. Construa um `ColumnTransformer` mínimo com imputação e one-hot encoding e conecte-o a uma regressão logística usada apenas como baseline.

# %% [markdown]
# ## Atividade 3
#
# 3. Confirme que `fit` recebe somente o treino e compare a saída da regressão logística com o Dummy.

# %% [markdown]
# ## Prática obrigatória 1
#
# 4. Adicione padronização somente às colunas numéricas que precisam dela.

# %% [markdown]
# ## Prática obrigatória 2
#
# 5. Teste uma categoria inédita com `handle_unknown='ignore'` e outra linha com mensalidade ausente, sem reajustar a pipeline.
#
# 6. Salve com `joblib.dump(modelo, "pipeline.joblib")`, recarregue com `joblib.load()` e confirme que as previsões antes e depois são iguais.
