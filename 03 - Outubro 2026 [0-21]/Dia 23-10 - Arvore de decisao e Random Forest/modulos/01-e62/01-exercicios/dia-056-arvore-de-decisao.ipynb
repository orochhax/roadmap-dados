# %% [markdown]
# ## Começo guiado
#
# **Dados de partida:** `dados/clientes_telecom.csv` e `dados/pedidos.csv`.
#
# Não crie uma base nova. Use os valores, arquivos ou tabelas já indicados e resolva uma atividade por vez. Execute a célula e confira o número, a tabela ou o gráfico antes de seguir.

# %% [markdown]
# # Árvore de decisão
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. [ ] Treine árvore de decisão com profundidades 1, 3, 5, 10 e sem limite.

# %% [markdown]
# ## Atividade 2
#
# 2. [ ] Visualize uma árvore pequena e traduza cinco divisões em regras de negócio.

# %% [markdown]
# ## Atividade 3
#
# 3. [ ] Compare desempenho de treino e validação para identificar overfitting.

# %% [markdown]
# ## Prática obrigatória 1
#
# 4. [ ] Varie `min_samples_leaf` e registre estabilidade.

# %% [markdown]
# ## Prática obrigatória 2
#
# 5. [ ] Crie uma árvore deliberadamente complexa e explique por que não deve ser usada apesar da métrica de treino.

# %% [markdown]
# ## Prática obrigatória — adaptação 1
#
# 1. [ ] Compare profundidade 3 e 10 com min_samples_leaf=20 no mesmo split e registre treino e validação.

# %% [markdown]
# ## Prática obrigatória — adaptação 2
#
# 2. [ ] Escolha uma previsão errada da árvore profunda e escreva as regras percorridas até a folha.
