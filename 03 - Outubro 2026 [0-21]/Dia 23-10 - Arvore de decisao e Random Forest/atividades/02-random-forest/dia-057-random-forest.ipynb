# %% [markdown]
# ## Começo guiado
#
# **Dados de partida:** `dados/clientes_telecom.csv` e `dados/pedidos.csv`.
#
# Não crie uma base nova. Use os valores, arquivos ou tabelas já indicados e resolva uma atividade por vez. Execute a célula e confira o número, a tabela ou o gráfico antes de seguir.

# %% [markdown]
# # Random Forest
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. Treine Random Forest variando número de árvores, profundidade e número de features.

# %% [markdown]
# ## Atividade 2
#
# 2. Compare variância de uma árvore única com a floresta em cinco seeds.

# %% [markdown]
# ## Atividade 3
#
# 3. Calcule importância por impureza e permutation importance; compare rankings.

# %% [markdown]
# ## Prática obrigatória 1
#
# 4. Meça tempo e tamanho do modelo.

# %% [markdown]
# ## Prática obrigatória 2
#
# 5. Escolha configuração considerando desempenho, estabilidade e custo de inferência.

# %% [markdown]
# ## Prática obrigatória — adaptação 1
#
# 1. Compare 50 e 300 árvores em cinco seeds, mantendo as demais configurações, e registre média e desvio da métrica.

# %% [markdown]
# ## Prática obrigatória — adaptação 2
#
# 2. Calcule permutation importance para a melhor configuração e compare as cinco primeiras com a importância por impureza.
