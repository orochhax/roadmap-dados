# %% [markdown]
# ## Começo guiado
#
# **Dados de partida:** `dados/clientes_telecom.csv` e `dados/pedidos.csv`.
#
# Não crie uma base nova. Use os valores, arquivos ou tabelas já indicados e resolva uma atividade por vez. Execute a célula e confira o número, a tabela ou o gráfico antes de seguir.

# %% [markdown]
# # Regularização
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. [ ] Treine regressão linear, Ridge e Lasso no mesmo conjunto padronizado.

# %% [markdown]
# ## Atividade 2
#
# 2. [ ] Varie `alpha` em pelo menos seis valores e registre coeficientes e métricas.

# %% [markdown]
# ## Atividade 3
#
# 3. [ ] Crie features altamente correlacionadas para observar instabilidade da regressão comum.

# %% [markdown]
# ## Prática obrigatória 1
#
# 4. [ ] Mostre quais coeficientes o Lasso zera e quando isso não significa causalidade.

# %% [markdown]
# ## Prática obrigatória 2
#
# 5. [ ] Escolha um modelo equilibrando erro, estabilidade e interpretação.

# %% [markdown]
# ## Prática obrigatória — adaptação 1
#
# 1. [ ] Compare Ridge e Lasso com alpha 0,01 e 10, mantendo split e escala iguais, e registre coeficientes e RMSE.

# %% [markdown]
# ## Prática obrigatória — adaptação 2
#
# 2. [ ] Duplique uma feature numérica com ruído mínimo e verifique como os coeficientes mudam nos três modelos.
