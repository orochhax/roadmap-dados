# %% [markdown]
# ## Começo guiado
#
# **Dados de partida:** `dados/clientes_telecom.csv` e `dados/pedidos.csv`.
#
# Não crie uma base nova. Use os valores, arquivos ou tabelas já indicados e resolva uma atividade por vez. Execute a célula e confira o número, a tabela ou o gráfico antes de seguir.

# %% [markdown]
# # Feature engineering para regressão
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. [ ] Crie features de data: mês, dia da semana, fim de semana e dias desde primeira compra.

# %% [markdown]
# ## Atividade 2
#
# 2. [ ] Crie transformações `log1p` para variável assimétrica e interações entre desconto e canal.

# %% [markdown]
# ## Atividade 3
#
# 3. [ ] Agrupe categorias raras com limiar explícito e documente impacto.

# %% [markdown]
# ## Prática obrigatória 1
#
# 4. [ ] Construa cada feature dentro da pipeline para evitar diferenças entre treino e inferência.

# %% [markdown]
# ## Prática obrigatória 2
#
# 5. [ ] Faça ablação: remova grupos de features e registre quanto cada grupo muda a métrica.

# %% [markdown]
# ## Prática obrigatória — adaptação 1
#
# 1. [ ] Agrupe categorias com frequência abaixo de 1% e depois abaixo de 5%; compare número de colunas e MAE.

# %% [markdown]
# ## Prática obrigatória — adaptação 2
#
# 2. [ ] Remova somente as features de interação e registre a variação da métrica no mesmo conjunto de validação.
