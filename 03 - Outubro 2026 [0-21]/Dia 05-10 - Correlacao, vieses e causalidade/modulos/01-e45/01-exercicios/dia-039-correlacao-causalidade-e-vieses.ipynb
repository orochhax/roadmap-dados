# %% [markdown]
# ## Começo guiado
#
# **Dados de partida:** `dados/clientes_telecom.csv`, `dados/incidentes.csv` e dados sintéticos gerados no notebook com seed 42.
#
# Não crie uma base nova. Use os valores, arquivos ou tabelas já indicados e resolva uma atividade por vez. Execute a célula e confira o número, a tabela ou o gráfico antes de seguir.

# %% [markdown]
# # Correlação, causalidade e vieses
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. [ ] Calcule Pearson e Spearman em duas relações e compare o que cada medida captura.

# %% [markdown]
# ## Atividade 2
#
# 2. [ ] Crie um exemplo de correlação sem causalidade e liste um possível confundidor.

# %% [markdown]
# ## Atividade 3
#
# 3. [ ] Reescreva três conclusões causais como associações compatíveis com dados observacionais.

# %% [markdown]
# ## Prática obrigatória 1
#
# 4. [ ] Construa um DAG simples depois de identificar exposição, resultado e confundidor.

# %% [markdown]
# ## Prática obrigatória 2
#
# 5. [ ] Construa um exemplo do paradoxo de Simpson com análise estratificada.
