# %% [markdown]
# ## Começo guiado
#
# **Dados de partida:** `dados/clientes_telecom.csv` e `dados/pedidos.csv`.
#
# Não crie uma base nova. Use os valores, arquivos ou tabelas já indicados e resolva uma atividade por vez. Execute a célula e confira o número, a tabela ou o gráfico antes de seguir.

# %% [markdown]
# # Regressão linear
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. [ ] Crie dados sintéticos lineares `y = 3x + 5 + ruído` e ajuste regressão linear.

# %% [markdown]
# ## Atividade 2
#
# 2. [ ] Recupere coeficiente e intercepto; compare com valores reais usados na geração.

# %% [markdown]
# ## Atividade 3
#
# 3. [ ] Use `pedidos.csv` para prever valor do pedido com variáveis permitidas.

# %% [markdown]
# ## Prática obrigatória 1
#
# 4. [ ] Plote resíduos versus predição e distribuição dos resíduos.

# %% [markdown]
# ## Prática obrigatória 2
#
# 5. [ ] Crie uma relação não linear e demonstre por que regressão linear simples falha.
#
# 6. [ ] Separe os pedidos acima do percentil 90 e compare o erro desse grupo com o restante.
