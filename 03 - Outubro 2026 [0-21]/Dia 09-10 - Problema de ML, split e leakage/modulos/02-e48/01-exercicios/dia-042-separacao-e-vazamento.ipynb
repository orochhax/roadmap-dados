# %% [markdown]
# ## Começo guiado
#
# **Dados de partida:** `dados/clientes_telecom.csv` e `dados/pedidos.csv`.
#
# Não crie uma base nova. Use os valores, arquivos ou tabelas já indicados e resolva uma atividade por vez. Execute a célula e confira o número, a tabela ou o gráfico antes de seguir.

# %% [markdown]
# # Separação e vazamento
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. [ ] Separe treino, validação e teste com proporção definida e compare a distribuição do alvo com e sem estratificação.

# %% [markdown]
# ## Atividade 2
#
# 2. [ ] Classifique colunas como disponíveis no momento da previsão ou como vazamento, justificando quando surgem.

# %% [markdown]
# ## Atividade 3
#
# 3. [ ] Desenhe um corte temporal simples e explique por que nenhum registro futuro pode participar do treino.

# %% [markdown]
# ## Prática obrigatória 1
#
# 4. [ ] Crie três features com leakage apenas como exemplos identificados; não as use em um modelo.

# %% [markdown]
# ## Prática obrigatória 2
#
# 5. [ ] Escreva um checklist curto de cinco perguntas para detectar vazamento.
#
# 6. [ ] Compare split aleatório e temporal usando a mesma métrica e explique qual representa melhor o uso real.
