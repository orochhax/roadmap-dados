# %% [markdown]
# ## Começo guiado
#
# **Dados de partida:** `dados/clientes_telecom.csv` e `dados/pedidos.csv`.
#
# Não crie uma base nova. Use os valores, arquivos ou tabelas já indicados e resolva uma atividade por vez. Execute a célula e confira o número, a tabela ou o gráfico antes de seguir.

# %% [markdown]
# # Definição do problema
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. [ ] Escolha um problema binário usando `clientes_telecom.csv`: prever churn nos próximos 30 dias; escreva alvo, unidade de previsão e horizonte temporal.

# %% [markdown]
# ## Atividade 2
#
# 2. [ ] Defina quem usará a previsão, qual ação será tomada e qual erro é mais caro.

# %% [markdown]
# ## Atividade 3
#
# 3. [ ] Liste 15 variáveis possíveis e classifique cada uma como disponível, indisponível, sensível ou potencial leakage.

# %% [markdown]
# ## Prática obrigatória 1
#
# 4. [ ] Crie baseline de negócio: prever todos como não churn e comparar com regra simples `chamados_90d >= 3`.

# %% [markdown]
# ## Prática obrigatória 2
#
# 5. [ ] Escreva `problem_statement.md` com objetivo, restrições, métrica primária, métricas secundárias e critério de sucesso.
#
# 6. [ ] Altere no documento o custo de falso negativo de R$500 para R$800 e revise somente a métrica primária e o critério de sucesso afetados.
#
# 7. [ ] Classifique `status_atual`, `data_cancelamento` e `motivo_cancelamento` como leakage e escreva quando cada coluna fica disponível.
