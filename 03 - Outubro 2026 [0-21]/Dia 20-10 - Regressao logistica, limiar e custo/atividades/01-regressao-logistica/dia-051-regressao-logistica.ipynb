# %% [markdown]
# ## Começo guiado
#
# **Dados de partida:** `dados/clientes_telecom.csv` e `dados/pedidos.csv`.
#
# Não crie uma base nova. Use os valores, arquivos ou tabelas já indicados e resolva uma atividade por vez. Execute a célula e confira o número, a tabela ou o gráfico antes de seguir.

# %% [markdown]
# # Regressão logística
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. Implemente regressão logística em dados sintéticos e interprete probabilidade e log-odds em nível conceitual.

# %% [markdown]
# ## Atividade 2
#
# 2. Treine no churn com pipeline completa e obtenha probabilidades, não apenas classes.

# %% [markdown]
# ## Atividade 3
#
# 3. Interprete sinal e magnitude de cinco coeficientes após padronização.

# %% [markdown]
# ## Prática obrigatória 1
#
# 4. Compare regressão logística com `DummyClassifier` e regra simples.

# %% [markdown]
# ## Prática obrigatória 2
#
# 5. Teste multicolinearidade e regularização; documente estabilidade dos coeficientes.

# %% [markdown]
# ## Prática obrigatória — adaptação 1
#
# 1. Treine a logística com C=0,1 e C=10 no mesmo split e compare cinco coeficientes padronizados.

# %% [markdown]
# ## Prática obrigatória — adaptação 2
#
# 2. Avalie probabilidades no grupo chamados_90d>=3 e compare a média com o grupo chamados_90d<3.
