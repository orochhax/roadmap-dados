# %% [markdown]
# # Dia 032 — Probabilidade básica
#
# **Data:** 15/09/2026
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Problema 1 — Complemento
#
# 1. [ ] De 240 chamados, 198 foram resolvidos. Calcule a probabilidade de escolher um chamado não resolvido.

# %% [markdown]
# ## Problema 2 — União
#
# 2. [ ] Em 1.000 clientes, 180 estão atrasados, 140 abriram três ou mais chamados e 60 pertencem aos dois grupos. Calcule P(atraso OU muitos chamados).

# %% [markdown]
# ## Problema 3 — Interseção
#
# 3. [ ] Usando os mesmos 1.000 clientes do problema anterior, calcule P(atraso E muitos chamados).

# %% [markdown]
# ## Problema 4 — Probabilidade condicional
#
# 4. [ ] Entre 500 clientes, 120 têm NPS até 4 e 72 desses cancelaram. Calcule P(churn | NPS até 4).

# %% [markdown]
# ## Problema 5 — Condicional inversa
#
# 5. [ ] Em uma base com 500 clientes e 100 churns, 72 churns tinham NPS até 4. Calcule P(NPS até 4 | churn) e explique por que não é a mesma pergunta do problema 4.

# %% [markdown]
# ## Problema 6 — Independência
#
# 6. [ ] Em 1.000 clientes, P(atraso)=0,20, P(churn)=0,10 e 35 clientes têm atraso e churn. Compare P(atraso E churn) com P(atraso)×P(churn).

# %% [markdown]
# ## Problema 7 — Bayes em churn
#
# 7. [ ] Há 1.000 clientes e 100 churns. Um alerta tem sensibilidade de 80% e falso positivo de 20%. Monte a tabela 2×2 e calcule P(churn | alerta).

# %% [markdown]
# ## Problema 8 — Bayes em fraude
#
# 8. [ ] Em 10.000 transações, 1% é fraude. Um detector identifica 90% das fraudes e alerta 5% das transações legítimas. Calcule P(fraude | alerta).

# %% [markdown]
# ## Problema 9 — Pelo menos um evento
#
# 9. [ ] A chance de indisponibilidade em cada dia é 10% e os três dias são independentes. Calcule a chance de ocorrer ao menos uma indisponibilidade em três dias.

# %% [markdown]
# ## Problema 10 — Exatamente dois eventos
#
# 10. [ ] Cada um de cinco clientes tem probabilidade de churn igual a 20%, com independência. Calcule a probabilidade de exatamente dois cancelarem.

# %% [markdown]
# ## Problema 11 — Comparação de bases
#
# 11. [ ] Dois alertas têm sensibilidade de 80% e falso positivo de 10%. Compare P(churn | alerta) quando a taxa-base de churn é 2% e quando é 20%.

# %% [markdown]
# ## Problema 12 — Decisão com probabilidades
#
# 12. [ ] Uma campanha custa R$20 por cliente. Um churn evitado vale R$300 e a oferta evita 30% dos churns abordados. Determine qual probabilidade mínima de churn torna o benefício esperado maior que o custo; registre as hipóteses usadas.

# %% [markdown]
# ## Atividade 2
#
# 2. [ ] Construa uma tabela 2x2 com 1.000 clientes, 100 churns e um alerta com sensibilidade 80% e falso positivo 20%; calcule `P(churn|alerta)`.

# %% [markdown]
# ## Atividade 3
#
# 3. [ ] Simule 10.000 lançamentos de moeda e dados com NumPy; compare frequência observada e probabilidade teórica.

# %% [markdown]
# ## Atividade 4
#
# 4. [ ] Crie dois eventos independentes e dois dependentes em dados sintéticos; mostre numericamente a diferença.

# %% [markdown]
# ## Atividade 5
#
# 5. [ ] Escreva três erros comuns ao interpretar probabilidade condicional.

# %% [markdown]
# ## Exercícios Extras Específicos — 1
#
# 1. [ ] Refaça o problema de Bayes com 2.000 clientes, 160 churns, sensibilidade de 75% e falso positivo de 10%.

# %% [markdown]
# ## Exercícios Extras Específicos — 2
#
# 2. [ ] Simule 100, 1.000 e 10.000 lançamentos da mesma moeda com seed 42 e compare a distância entre frequência e probabilidade teórica.
