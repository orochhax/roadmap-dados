# %% [markdown]
# # Dia 042 — Separação e vazamento
#
# **Data:** 29/09/2026
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. [ ] Separe treino, validação e teste com proporção 60/20/20 e `random_state` fixo.

# %% [markdown]
# ## Atividade 2
#
# 2. [ ] Repita a separação de forma estratificada e compare proporção de churn em cada conjunto.

# %% [markdown]
# ## Atividade 3
#
# 3. [ ] Crie três features com leakage proposital, como `data_cancelamento`, `motivo_cancelamento` e `status_atual`; demonstre o aumento artificial da métrica.

# %% [markdown]
# ## Atividade 4
#
# 4. [ ] Remova o leakage e registre a queda de desempenho como evidência de correção.

# %% [markdown]
# ## Atividade 5
#
# 5. [ ] Escreva um checklist de 10 perguntas para detectar vazamento antes da modelagem.

# %% [markdown]
# ## Exercícios Extras Específicos — 1
#
# 1. [ ] Compare o split estratificado aleatório com um corte temporal usando a mesma base e registre a proporção de churn em cada conjunto.

# %% [markdown]
# ## Exercícios Extras Específicos — 2
#
# 2. [ ] Treine uma versão com status_atual e outra sem essa coluna; use a diferença de métrica para documentar o vazamento.
