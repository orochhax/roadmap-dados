# %% [markdown]
# # Dia 039 — Correlação, causalidade e vieses
#
# **Data:** 24/09/2026
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. [ ] Calcule correlação Pearson e Spearman entre mensalidade, chamados, NPS e churn codificado.

# %% [markdown]
# ## Atividade 2
#
# 2. [ ] Crie três exemplos sintéticos: correlação sem causalidade, causalidade com baixa correlação linear e paradoxo de Simpson.

# %% [markdown]
# ## Atividade 3
#
# 3. [ ] Desenhe um DAG simples para relação entre plano, renda, mensalidade e churn.

# %% [markdown]
# ## Atividade 4
#
# 4. [ ] Liste possíveis confundidores em uma análise de cancelamento.

# %% [markdown]
# ## Atividade 5
#
# 5. [ ] Reescreva cinco frases causais como associações honestas quando o desenho não sustenta causalidade.

# %% [markdown]
# ## Exercícios Extras Específicos — 1
#
# 1. [ ] Construa um exemplo de Simpson com duas cidades em que a associação geral tenha sinal diferente das associações por cidade.

# %% [markdown]
# ## Exercícios Extras Específicos — 2
#
# 2. [ ] Escolha uma conclusão causal do rascunho e reescreva-a como associação, citando o confundidor que ainda não foi controlado.
