# %% [markdown]
# # Dia 061 — Feature engineering
#
# **Data:** 26/10/2026
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. [ ] Crie pelo menos oito features de churn agrupadas em comportamento, financeiro, suporte e relacionamento.

# %% [markdown]
# ## Atividade 2
#
# 2. [ ] Defina para cada feature: fórmula, fonte, momento de disponibilidade e risco de leakage.

# %% [markdown]
# ## Atividade 3
#
# 3. [ ] Implemente features em funções ou transformer customizado.

# %% [markdown]
# ## Atividade 4
#
# 4. [ ] Faça análise de ablação por grupo.

# %% [markdown]
# ## Atividade 5
#
# 5. [ ] Elimine features que dependam do futuro ou duplicam o alvo.

# %% [markdown]
# ## Exercícios Extras Específicos — 1
#
# 1. [ ] Crie a feature chamados_por_mes usando somente chamados anteriores à data de referência e documente a fórmula.

# %% [markdown]
# ## Exercícios Extras Específicos — 2
#
# 2. [ ] Remova todas as features financeiras e refaça a ablação no mesmo split para medir a perda de desempenho.
