# %% [markdown]
# # Dia 052 — Limiar e custo
#
# **Data:** 13/10/2026
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. [ ] Calcule previsões para limiares 0.2, 0.3, 0.5, 0.7 e 0.8.

# %% [markdown]
# ## Atividade 2
#
# 2. [ ] Para cada limiar, registre TP, FP, FN, TN, precision, recall e custo total.

# %% [markdown]
# ## Atividade 3
#
# 3. [ ] Use custos definidos: FN=R$500, FP=R$20, TP=R$80 de campanha e benefício esperado de R$300.

# %% [markdown]
# ## Atividade 4
#
# 4. [ ] Escolha o limiar de menor custo respeitando recall mínimo de 70%.

# %% [markdown]
# ## Atividade 5
#
# 5. [ ] Crie gráfico custo versus limiar e escreva recomendação executiva.

# %% [markdown]
# ## Exercícios Extras Específicos — 1
#
# 1. [ ] Refaça a tabela de limiares aumentando o custo de FP de R$20 para R$50 e mantenha os demais valores.

# %% [markdown]
# ## Exercícios Extras Específicos — 2
#
# 2. [ ] Escolha novamente o limiar exigindo recall mínimo de 80% em vez de 70% e registre a troca de custo e volume.
