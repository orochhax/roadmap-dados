# %% [markdown]
# # Dia 047 — Métricas de regressão
#
# **Data:** 06/10/2026
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1 — dados iniciais
#
# 1. [ ] Use os cinco pares abaixo para calcular MAE, MSE, RMSE, R² e MAPE manualmente e depois conferir com biblioteca. O quarto valor real é zero; trate essa limitação do MAPE explicitamente.

# %%
y_real = [100, 120, 80, 0, 200]
y_previsto = [90, 135, 70, 10, 180]

# ESCREVA SUA SOLUÇÃO ABAIXO:

# %% [markdown]
# ## Atividade 2
#
# 2. [ ] Crie um caso com valor real zero e mostre por que MAPE pode quebrar.

# %% [markdown]
# ## Atividade 3
#
# 3. [ ] Compare dois modelos: um com poucos erros grandes e outro com muitos erros pequenos.

# %% [markdown]
# ## Atividade 4
#
# 4. [ ] Escolha a métrica mais coerente para previsão de receita e justifique custo dos erros.

# %% [markdown]
# ## Atividade 5
#
# 5. [ ] Crie intervalo de erro por faixa de valor e verifique se o modelo piora nos pedidos maiores.

# %% [markdown]
# ## Exercícios Extras Específicos — 1
#
# 1. [ ] Use y_real=[100, 120, 80, 0, 200] e y_pred=[90, 135, 70, 10, 180] para calcular as métricas e tratar MAPE com zero.

# %% [markdown]
# ## Exercícios Extras Específicos — 2
#
# 2. [ ] Separe os dois maiores valores reais e compare o MAE desse recorte com o MAE dos três menores.
