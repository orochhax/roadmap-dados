# %% [markdown]
# # Dia 116 — Definição do produto integrador
#
# **Data:** 11/01/2027
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. [ ] Escolha um produto integrador entre churn, crédito, forecasting ou RAG e defina usuário, decisão e valor.

# %% [markdown]
# ## Atividade 2
#
# 2. [ ] Escreva escopo de cinco dias com backlog priorizado MoSCoW.

# %% [markdown]
# ## Atividade 3
#
# 3. [ ] Desenhe arquitetura e fluxo de dados.

# %% [markdown]
# ## Atividade 4
#
# 4. [ ] Defina métricas técnicas, de negócio e de experiência.

# %% [markdown]
# ## Atividade 5
#
# 5. [ ] Abra issues e marcos no GitHub.

# %% [markdown]
# ## Exercícios Extras Específicos — 1
#
# 1. [ ] Acrescente ao backlog um caso de usuário com entrada incompleta e classifique-o como Must, Should, Could ou Won't.

# %% [markdown]
# ## Exercícios Extras Específicos — 2
#
# 2. [ ] Reduza o prazo de cinco para três dias e registre quais dois itens serão cortados sem remover o valor principal.
