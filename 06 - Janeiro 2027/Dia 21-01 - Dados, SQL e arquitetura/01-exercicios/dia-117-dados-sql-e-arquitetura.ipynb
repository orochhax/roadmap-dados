# %% [markdown]
# # Dia 117 — Dados, SQL e arquitetura
#
# **Data:** 12/01/2027
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. [ ] Crie ou revise esquema SQL e pipeline de formação da base.

# %% [markdown]
# ## Atividade 2
#
# 2. [ ] Adicione testes de qualidade e dicionário.

# %% [markdown]
# ## Atividade 3
#
# 3. [ ] Desenhe arquitetura de execução e deploy.

# %% [markdown]
# ## Atividade 4
#
# 4. [ ] Garanta que uma única instrução reproduza a base.

# %% [markdown]
# ## Atividade 5
#
# 5. [ ] Faça revisão de segurança e privacidade.

# %% [markdown]
# ## Exercícios Extras Específicos — 1
#
# 1. [ ] Remova cliente_id de uma cópia da entrada e faça a checagem de qualidade impedir a formação da base.

# %% [markdown]
# ## Exercícios Extras Específicos — 2
#
# 2. [ ] Execute a instrução única duas vezes e confirme que a segunda execução não duplica linhas nem artefatos.
