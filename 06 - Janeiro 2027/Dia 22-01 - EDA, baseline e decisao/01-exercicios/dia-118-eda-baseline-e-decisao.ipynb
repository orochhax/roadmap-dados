# %% [markdown]
# # Dia 118 — EDA, baseline e decisão
#
# **Data:** 13/01/2027
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. [ ] Faça EDA focada nas hipóteses do produto.

# %% [markdown]
# ## Atividade 2
#
# 2. [ ] Implemente baseline de negócio e técnico.

# %% [markdown]
# ## Atividade 3
#
# 3. [ ] Defina limiar/regra de decisão.

# %% [markdown]
# ## Atividade 4
#
# 4. [ ] Calcule impacto esperado e cenário de pior caso.

# %% [markdown]
# ## Atividade 5
#
# 5. [ ] Produza memorando de decisão de uma página.

# %% [markdown]
# ## Exercícios Extras Específicos — 1
#
# 1. [ ] Refaça a decisão aumentando o custo do pior erro em 50% e registre se limiar ou ação recomendada muda.

# %% [markdown]
# ## Exercícios Extras Específicos — 2
#
# 2. [ ] Calcule o impacto somente para Salvador e compare tamanho e direção com o cenário geral.
