# %% [markdown]
# # Dia 119 — Modelo, IA e interface
#
# **Data:** 14/01/2027
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. [ ] Treine/integre o componente principal: modelo preditivo ou RAG.

# %% [markdown]
# ## Atividade 2
#
# 2. [ ] Crie API, dashboard ou interface mínima.

# %% [markdown]
# ## Atividade 3
#
# 3. [ ] Adicione explicações/fontes e tratamento de incerteza.

# %% [markdown]
# ## Atividade 4
#
# 4. [ ] Teste ponta a ponta com 20 casos.

# %% [markdown]
# ## Atividade 5
#
# 5. [ ] Registre métricas, latência, custo e falhas.

# %% [markdown]
# ## Exercícios Extras Específicos — 1
#
# 1. [ ] Inclua um caso com campos ausentes entre os 20 testes ponta a ponta e faça a interface explicar o que precisa ser corrigido.

# %% [markdown]
# ## Exercícios Extras Específicos — 2
#
# 2. [ ] Simule latência de 2 segundos no componente principal e registre a experiência da interface e o timeout escolhido.
