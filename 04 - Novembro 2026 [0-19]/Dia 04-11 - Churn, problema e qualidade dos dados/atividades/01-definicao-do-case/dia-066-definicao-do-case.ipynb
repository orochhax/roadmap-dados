# %% [markdown]
# ## Começo guiado
#
# **Dados de partida:** `dados/clientes_telecom.csv` e `dados/pedidos.csv`.
#
# Não crie uma base nova. Use os valores, arquivos ou tabelas já indicados e resolva uma atividade por vez. Execute a célula e confira o número, a tabela ou o gráfico antes de seguir.

# %% [markdown]
# # Definição do case
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. Defina o case de churn em telecom com pergunta: quais clientes têm risco de cancelar em 30 dias e quais ações de retenção são economicamente viáveis.

# %% [markdown]
# ## Atividade 2
#
# 2. Escreva personas dos usuários do produto: gerente de retenção, analista e atendente.

# %% [markdown]
# ## Atividade 3
#
# 3. Crie matriz de decisões com ação, custo, benefício, responsável e risco.

# %% [markdown]
# ## Prática obrigatória 1
#
# 4. Defina escopo mínimo do projeto e lista explícita do que ficará fora.

# %% [markdown]
# ## Prática obrigatória 2
#
# 5. Reduza o orçamento de retenção em 30% e marque quais ações do escopo mínimo seriam mantidas ou cortadas.

# %% [markdown]
# ## Evidência da decisão
#
# Registre os critérios usados para manter ou cortar cada ação.

# %% [markdown]
# ## Limitação
#
# Registre uma limitação concreta da decisão sob orçamento reduzido.
