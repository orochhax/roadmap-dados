# %% [markdown]
# ## Começo guiado
#
# **Dados de partida:** `dados/energia.csv`.
#
# Não crie uma base nova. Use os valores, arquivos ou tabelas já indicados e resolva uma atividade por vez. Execute a célula e confira o número, a tabela ou o gráfico antes de seguir.

# %% [markdown]
# # Baselines temporais
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. Implemente baselines: último valor, média móvel de 7 dias, média do mesmo dia da semana e média sazonal.

# %% [markdown]
# ## Atividade 2
#
# 2. Use validação walk-forward em pelo menos três janelas.

# %% [markdown]
# ## Atividade 3
#
# 3. Calcule MAE, RMSE e MAPE/SMAPE quando adequado.

# %% [markdown]
# ## Prática obrigatória 1
#
# 4. Compare desempenho por períodos de alta e baixa demanda.

# %% [markdown]
# ## Prática obrigatória 2
#
# 5. Escolha baseline oficial que qualquer modelo deve superar.

# %% [markdown]
# ## Prática obrigatória — adaptação 1
#
# 1. Compare horizonte de 7 e 14 dias nas mesmas três janelas walk-forward e registre MAE por horizonte.

# %% [markdown]
# ## Prática obrigatória — adaptação 2
#
# 2. Avalie o baseline oficial separadamente em dias úteis e fins de semana.
