# %% [markdown]
# ## Começo guiado
#
# **Dados de partida:** `dados/credito.csv`.
#
# Não crie uma base nova. Use os valores, arquivos ou tabelas já indicados e resolva uma atividade por vez. Execute a célula e confira o número, a tabela ou o gráfico antes de seguir.

# %% [markdown]
# # Problema e governança
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. [ ] Defina case de risco: prever default em 90 dias e apoiar aprovação, revisão ou rejeição.

# %% [markdown]
# ## Atividade 2
#
# 2. [ ] Liste variáveis proibidas, sensíveis ou potencialmente discriminatórias.

# %% [markdown]
# ## Atividade 3
#
# 3. [ ] Defina custos de falso negativo, falso positivo e revisão manual.

# %% [markdown]
# ## Prática obrigatória 1
#
# 4. [ ] Crie política de governança com responsável, frequência de revisão e trilha de auditoria.

# %% [markdown]
# ## Prática obrigatória 2
#
# 5. [ ] Escreva critérios de sucesso técnico, econômico e de equidade.

# %% [markdown]
# ## Prática obrigatória — adaptação 1
#
# 1. [ ] Acrescente à política a regra de revisão humana para probabilidade entre 0,40 e 0,60 e calcule o volume dessa faixa.

# %% [markdown]
# ## Prática obrigatória — adaptação 2
#
# 2. [ ] Liste quais colunas seriam removidas se contivessem atributo sensível ou uma proxy direta de renda familiar protegida.
