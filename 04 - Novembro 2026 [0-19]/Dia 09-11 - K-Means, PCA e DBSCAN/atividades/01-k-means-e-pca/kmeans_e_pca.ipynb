# %% [markdown]
# # K-Means e PCA
#
# > Notebook preparado somente com enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## 1. Dados e proteção contra vazamento
#
# Carregue `dados/clientes_telecom.csv`. Use apenas `mensalidade`, `nps`, `chamados_90d`, `atraso_dias` e `tempo_cliente_meses`. Registre por que identificadores, `churn`, datas e informações de cancelamento ficam fora do ajuste.

# %%
# ESCREVA AQUI

# %% [markdown]
# ## 2. Escalas e padronização
#
# Compare mínimo, máximo, média e desvio das cinco variáveis. Aplique `StandardScaler` e confira numericamente o efeito da transformação.

# %%
# ESCREVA AQUI

# %% [markdown]
# ## 3. Comparação de valores de k
#
# Treine K-Means para `k` de 2 a 8 com `random_state=42`. Monte uma tabela com `k`, inércia, silhouette e tamanho do menor cluster. Compare também uma execução sem padronização.

# %%
# ESCREVA AQUI

# %% [markdown]
# ## 4. PCA e perfis
#
# Aplique PCA com dois componentes para visualizar os grupos. Registre a variância explicada individual e acumulada. Depois, volte à escala original e descreva tamanho e médias de cada cluster.

# %%
# ESCREVA AQUI

# %% [markdown]
# ## 5. Teste controlado obrigatório
#
# Crie quatro pontos: dois próximos de `(0, 0)` e dois próximos de `(10, 10)`. Antes de executar, escreva o resultado esperado. Depois, confirme se os pontos próximos ficaram juntos e os grupos distantes separados, ignorando o número atribuído a cada cluster.

# %%
# Resultado esperado:
# Resultado observado:
# ESCREVA AQUI

# %% [markdown]
# ## 6. Decisão
#
# Justifique o `k` escolhido, explique por que a padronização foi necessária, descreva uma utilidade possível e registre uma limitação concreta.
