# %% [markdown]
# # DBSCAN e avaliação de clusters
#
# > Notebook preparado somente com enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## 1. Experimento com formato não circular
#
# Gere dados com `make_moons`, padronize-os e compare visualmente K-Means e DBSCAN. Antes de executar, registre qual método você espera que represente melhor os dois formatos e por quê.

# %%
# Hipótese antes da execução:
# ESCREVA AQUI

# %% [markdown]
# ## 2. Dados de clientes
#
# Recarregue `dados/clientes_telecom.csv`, selecione as mesmas cinco variáveis da sessão anterior e faça novamente a padronização. O notebook precisa executar sozinho.

# %%
# ESCREVA AQUI

# %% [markdown]
# ## 3. Busca de parâmetros
#
# Teste pelo menos quatro valores de `eps` e três de `min_samples`. Para cada combinação, registre número de clusters, percentual de ruído, silhouette e Davies-Bouldin. Não calcule uma métrica quando os rótulos não permitirem.

# %%
# ESCREVA AQUI

# %% [markdown]
# ## 4. Caso de borda obrigatório
#
# Force uma configuração que produza apenas um grupo ou somente ruído. Confirme que o código não quebra, não inventa uma métrica e informa por que ela não pode ser calculada.

# %%
# Resultado esperado:
# Resultado observado:
# ESCREVA AQUI

# %% [markdown]
# ## 5. Comparação e perfis
#
# Compare a melhor configuração válida de DBSCAN com o K-Means escolhido. Considere métricas, cobertura, sensibilidade aos parâmetros e interpretação. Descreva os grupos na escala original e inspecione registros classificados como ruído.

# %%
# ESCREVA AQUI

# %% [markdown]
# ## 6. Uso descritivo do churn e recomendação
#
# Somente depois de formar os grupos, compare descritivamente a taxa de `churn`. Explique por que isso não transforma churn em variável de treino nem demonstra causalidade. Preencha `03-evidencias/recomendacao_clusterizacao.md`.
