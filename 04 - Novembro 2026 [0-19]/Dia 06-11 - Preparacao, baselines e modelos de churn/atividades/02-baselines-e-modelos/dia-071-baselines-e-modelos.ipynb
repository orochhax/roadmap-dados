# %% [markdown]
# ## Começo guiado
#
# **Dados de partida:** `dados/clientes_telecom.csv` e `dados/pedidos.csv`.
#
# Não crie uma base nova. Use os valores, arquivos ou tabelas já indicados e resolva uma atividade por vez. Execute a célula e confira o número, a tabela ou o gráfico antes de seguir.

# %% [markdown]
# # Baselines e modelos
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. Treine regressão logística e um modelo de árvore usando a mesma pipeline e validação.

# %% [markdown]
# ## Atividade 2
#
# 2. Compare média, desvio, custo e tempo em uma tabela única.

# %% [markdown]
# ## Atividade 3
#
# 3. Analise dez erros críticos e escolha campeão e challenger com critérios definidos antes do resultado.

# %% [markdown]
# ## Prática obrigatória 1
#
# 4. Amplie a análise para 20 erros críticos e registre se os padrões encontrados nos dez primeiros permanecem.

# %% [markdown]
# ## Registro da análise de erros
#
# Registre o padrão observado, a contagem e uma hipótese de causa.

# %% [markdown]
# ## Prática obrigatória — adaptação 1
#
# 1. Compare campeão e challenger no segmento plano Básico 100 e registre tamanho, custo, recall e precision.

# %% [markdown]
# ## Prática obrigatória — adaptação 2
#
# 2. Aumente o custo de falso negativo de R$500 para R$800 e confira se a escolha do campeão muda.
