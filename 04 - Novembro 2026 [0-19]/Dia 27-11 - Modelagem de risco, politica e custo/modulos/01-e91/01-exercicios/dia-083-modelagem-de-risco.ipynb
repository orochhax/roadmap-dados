# %% [markdown]
# ## Começo guiado
#
# **Dados de partida:** `dados/credito.csv`.
#
# Não crie uma base nova. Use os valores, arquivos ou tabelas já indicados e resolva uma atividade por vez. Execute a célula e confira o número, a tabela ou o gráfico antes de seguir.

# %% [markdown]
# # Modelagem de risco
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. [ ] Treine regressão logística como scorecard básico e modelos de árvore.

# %% [markdown]
# ## Atividade 2
#
# 2. [ ] Avalie ROC-AUC, PR-AUC, KS, calibração e matriz de confusão.

# %% [markdown]
# ## Atividade 3
#
# 3. [ ] Faça validação temporal, não apenas aleatória.

# %% [markdown]
# ## Prática obrigatória 1
#
# 4. [ ] Analise estabilidade e desempenho por segmentos.

# %% [markdown]
# ## Prática obrigatória 2
#
# 5. [ ] Escolha modelo explicável compatível com política de crédito.

# %% [markdown]
# ## Prática obrigatória — adaptação 1
#
# 1. [ ] Compare calibração e KS no conjunto temporal final para logística e o melhor modelo de árvore.

# %% [markdown]
# ## Prática obrigatória — adaptação 2
#
# 2. [ ] Calcule as métricas separadamente para contratos com prazo até 12 meses e acima de 24 meses.
