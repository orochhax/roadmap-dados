# %% [markdown]
# ## Começo guiado
#
# **Dados de partida:** `dados/clientes_telecom.csv` e `dados/pedidos.csv`.
#
# Não crie uma base nova. Use os valores, arquivos ou tabelas já indicados e resolva uma atividade por vez. Execute a célula e confira o número, a tabela ou o gráfico antes de seguir.

# %% [markdown]
# # SQL do projeto
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. Crie esquema SQL com tabelas de clientes, planos, chamados e pagamentos.

# %% [markdown]
# ## Atividade 2
#
# 2. Escreva consultas para formar features agregadas em janelas de 30, 60 e 90 dias.

# %% [markdown]
# ## Atividade 3
#
# 3. Valide granularidade: uma linha por cliente na data de referência.

# %% [markdown]
# ## Prática obrigatória 1
#
# 4. Crie testes de unicidade, ausência de chaves e totais antes/depois dos joins.

# %% [markdown]
# ## Prática obrigatória 2
#
# 5. Exporte `base_modelagem.csv` e compare cinco linhas com cálculo manual.

# %% [markdown]
# ## Prática obrigatória — adaptação 1
#
# 1. Crie a feature quantidade_chamados_60d e compare cinco clientes com uma contagem manual na tabela de chamados.

# %% [markdown]
# ## Prática obrigatória — adaptação 2
#
# 2. Duplique um pagamento, execute o teste de unicidade e impeça a exportação da base enquanto o problema existir.
