# %% [markdown]
# ## Começo guiado
#
# **Dados de partida:** `dados/clientes_telecom.csv` e `dados/pedidos.csv`.
#
# Não crie uma base nova. Use os valores, arquivos ou tabelas já indicados e resolva uma atividade por vez. Execute a célula e confira o número, a tabela ou o gráfico antes de seguir.

# %% [markdown]
# # EDA orientada a churn
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. [ ] Escreva quatro hipóteses de churn antes de gerar gráficos.

# %% [markdown]
# ## Atividade 2
#
# 2. [ ] Teste cada hipótese com tabela, métrica e visualização apropriada, sempre mostrando o tamanho dos grupos.

# %% [markdown]
# ## Atividade 3
#
# 3. [ ] Produza `insights_eda.md` com evidência, impacto, cautela e próxima análise para as duas hipóteses mais úteis.

# %% [markdown]
# ## Prática obrigatória 1
#
# 4. [ ] Teste a hipótese 'clientes com três ou mais chamados têm maior churn' com tabela, gráfico e tamanho dos dois grupos.

# %% [markdown]
# ## Prática obrigatória 2
#
# 5. [ ] Repita a análise somente em Salvador e registre se a direção da associação permanece.

# %% [markdown]
# ## Evidência da hipótese
#
# Registre tamanho dos grupos, resultado observado e uma limitação da comparação.

# %% [markdown]
# ## Conclusão do recorte
#
# Registre se o resultado de Salvador sustenta ou enfraquece a hipótese inicial.
