# %% [markdown]
# ## Começo guiado
#
# **Dados de partida:** `dados/clientes_telecom.csv` e `dados/pedidos.csv`.
#
# Não crie uma base nova. Use os valores, arquivos ou tabelas já indicados e resolva uma atividade por vez. Execute a célula e confira o número, a tabela ou o gráfico antes de seguir.

# %% [markdown]
# # Relatório e dashboard
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. Crie dashboard com visão geral, segmentos de risco, drivers e simulação de política.

# %% [markdown]
# ## Atividade 2
#
# 2. Valide números contra SQL/notebook.

# %% [markdown]
# ## Atividade 3
#
# 3. Escreva relatório técnico e resumo executivo.

# %% [markdown]
# ## Prática obrigatória 1
#
# 4. Adicione seção de limitações e plano de monitoramento.

# %% [markdown]
# ## Registro de monitoramento
#
# Registre indicador, frequência, limite de alerta e responsável.

# %% [markdown]
# ## Prática obrigatória — adaptação 1
#
# 1. Adicione ao dashboard um filtro de plano e valide o total exibido para Básico 100 contra o notebook.

# %% [markdown]
# ## Prática obrigatória — adaptação 2
#
# 2. Peça a uma pessoa para localizar o volume de alto risco em até 30 segundos e registre uma ambiguidade concreta encontrada.
