# %% [markdown]
# ## Começo guiado
#
# **Dados de partida:** `dados/clientes_telecom.csv`, `dados/incidentes.csv` e dados sintéticos gerados no notebook com seed 42.
#
# Não crie uma base nova. Use os valores, arquivos ou tabelas já indicados e resolva uma atividade por vez. Execute a célula e confira o número, a tabela ou o gráfico antes de seguir.

# %% [markdown]
# # Probabilidade básica
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Problema 1 — Complemento
#
# 1. De 240 chamados, 198 foram resolvidos. Calcule a probabilidade de escolher um chamado não resolvido.

# %% [markdown]
# ## Problema 2 — União
#
# 2. Em 1.000 clientes, 180 estão atrasados, 140 abriram três ou mais chamados e 60 pertencem aos dois grupos. Calcule P(atraso OU muitos chamados).

# %% [markdown]
# ## Problema 3 — Interseção
#
# 3. Usando os mesmos 1.000 clientes do problema anterior, calcule P(atraso E muitos chamados).

# %% [markdown]
# ## Problema 4 — Probabilidade condicional
#
# 4. Entre 500 clientes, 120 têm NPS até 4 e 72 desses cancelaram. Calcule P(churn | NPS até 4).

# %% [markdown]
# ## Problema 5 — Condicional inversa
#
# 5. Em uma base com 500 clientes e 100 churns, 72 churns tinham NPS até 4. Calcule P(NPS até 4 | churn) e explique por que não é a mesma pergunta do problema 4.

# %% [markdown]
# ## Problema 6 — Independência
#
# 6. Em 1.000 clientes, P(atraso)=0,20, P(churn)=0,10 e 35 clientes têm atraso e churn. Compare P(atraso E churn) com P(atraso)×P(churn).

# %% [markdown]
# ## Atividade 2
#
# 2. Construa uma tabela 2x2 com 1.000 clientes, 100 churns e um alerta com sensibilidade 80% e falso positivo 20%; calcule `P(churn|alerta)`.

# %% [markdown]
# ## Atividade 3
#
# 3. Simule lançamentos com NumPy em dois tamanhos de amostra e compare frequência observada e probabilidade teórica.

# %% [markdown]
# ## Prática obrigatória 1
#
# 4. Crie dois eventos independentes e dois dependentes em dados sintéticos; mostre numericamente a diferença.

# %% [markdown]
# ## Prática obrigatória 2
#
# 5. Refaça o problema de Bayes com 2.000 clientes, 160 churns, sensibilidade de 75% e falso positivo de 10%.
#
# 6. Simule 100, 1.000 e 10.000 lançamentos da mesma moeda com seed 42 e compare a distância entre frequência e probabilidade teórica.
