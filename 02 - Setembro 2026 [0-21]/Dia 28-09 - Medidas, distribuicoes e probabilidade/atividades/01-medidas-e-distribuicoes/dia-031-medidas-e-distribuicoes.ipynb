# %% [markdown]
# ## Começo guiado
#
# **Dados de partida:** `dados/clientes_telecom.csv`, `dados/incidentes.csv` e dados sintéticos gerados no notebook com seed 42.
#
# Não crie uma base nova. Use os valores, arquivos ou tabelas já indicados e resolva uma atividade por vez. Execute a célula e confira o número, a tabela ou o gráfico antes de seguir.

# %% [markdown]
# # Medidas e distribuições
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. Com `clientes_telecom.csv`, calcule média, mediana, moda, variância, desvio, quartis, IQR e amplitude para mensalidade, NPS e chamados.

# %% [markdown]
# ## Atividade 2
#
# 2. Crie duas distribuições com mesma média e desvios diferentes; mostre por que a média isolada engana.

# %% [markdown]
# ## Atividade 3
#
# 3. Compare métricas com e sem um outlier extremo inserido manualmente.

# %% [markdown]
# ## Prática obrigatória 1
#
# 4. Faça histogramas e boxplots e escreva a forma da distribuição: simétrica, assimétrica ou multimodal.

# %% [markdown]
# ## Prática obrigatória 2
#
# 5. Explique em linguagem de negócio quando mediana é mais adequada que média.
#
# 6. Calcule as mesmas medidas somente para Salvador e compare o tamanho desse grupo com o total antes de interpretar a diferença.
