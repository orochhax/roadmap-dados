# %% [markdown]
# ## Começo guiado
#
# **Dados de partida:** `dados/incidentes.csv`, `dados/clientes_telecom.csv`, `dados/pedidos.csv` e `dados/metas_cidades.csv`.
#
# Não crie uma base nova. Use os valores, arquivos ou tabelas já indicados e resolva uma atividade por vez. Execute a célula e confira o número, a tabela ou o gráfico antes de seguir.

# %% [markdown]
# # Dashboard introdutório
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. [ ] Defina um público-alvo para o dashboard: gerente de operações de telecom; escreva cinco decisões que ele precisa tomar.

# %% [markdown]
# ## Atividade 2
#
# 2. [ ] Crie no Power BI ou alternativa quatro indicadores: incidentes, duração média, clientes afetados e percentual dentro da meta.

# %% [markdown]
# ## Atividade 3
#
# 3. [ ] Adicione filtros de período, cidade e severidade; crie duas páginas: visão executiva e diagnóstico.

# %% [markdown]
# ## Prática obrigatória 1
#
# 4. [ ] Valide cada número do dashboard contra uma consulta ou cálculo em pandas.

# %% [markdown]
# ## Prática obrigatória 2
#
# 5. [ ] Escreva `dicionario_metricas.md` com fórmula, fonte, periodicidade e risco de interpretação de cada indicador.
#
# 6. [ ] Crie uma tabela de validação dos quatro indicadores somente para severidade P1 e compare com a página executiva sob o mesmo filtro.
