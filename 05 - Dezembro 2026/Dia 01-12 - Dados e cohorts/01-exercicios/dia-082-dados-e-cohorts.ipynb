# %% [markdown]
# # Dia 082 — Dados e cohorts
#
# **Data:** 24/11/2026
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. [ ] Carregue `credito.csv`, faça qualidade e EDA da taxa de default.

# %% [markdown]
# ## Atividade 2
#
# 2. [ ] Crie cohorts por mês de concessão e acompanhe default P1/P2/P3 quando possível.

# %% [markdown]
# ## Atividade 3
#
# 3. [ ] Analise default por faixas de renda, dívida, atrasos e tempo de emprego.

# %% [markdown]
# ## Atividade 4
#
# 4. [ ] Valide estabilidade temporal das variáveis.

# %% [markdown]
# ## Atividade 5
#
# 5. [ ] Crie dicionário de features e regras de exclusão.

# %% [markdown]
# ## Exercícios Extras Específicos — 1
#
# 1. [ ] Compare default para renda abaixo de R$3.000 e acima de R$8.000, informando também o tamanho dos grupos.

# %% [markdown]
# ## Exercícios Extras Específicos — 2
#
# 2. [ ] Separe os últimos três meses de concessão e compare a distribuição das cinco principais variáveis com o período anterior.
