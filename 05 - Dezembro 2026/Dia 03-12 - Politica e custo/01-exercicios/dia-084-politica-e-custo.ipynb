# %% [markdown]
# # Dia 084 — Política e custo
#
# **Data:** 26/11/2026
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. [ ] Converta probabilidade em faixas de risco A–E.

# %% [markdown]
# ## Atividade 2
#
# 2. [ ] Defina política de aprovar, revisar ou rejeitar por faixa.

# %% [markdown]
# ## Atividade 3
#
# 3. [ ] Simule lucro/prejuízo com taxas, perda esperada e custo operacional.

# %% [markdown]
# ## Atividade 4
#
# 4. [ ] Teste cenários de mudança na taxa de default.

# %% [markdown]
# ## Atividade 5
#
# 5. [ ] Crie regra para casos sem informação suficiente e revisão humana.

# %% [markdown]
# ## Exercícios Extras Específicos — 1
#
# 1. [ ] Aumente a perda em caso de default em 30% e recalcule lucro/prejuízo por faixa A–E.

# %% [markdown]
# ## Exercícios Extras Específicos — 2
#
# 2. [ ] Envie para revisão humana todos os casos com renda ou tempo de emprego ausente e conte o volume afetado.
