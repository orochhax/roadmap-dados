# %% [markdown]
# # Dia 078 — Modelos tradicionais
#
# **Data:** 18/11/2026
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. [ ] Treine regressão linear com lags, árvore/Random Forest e modelo estatístico simples como Holt-Winters ou ARIMA, se disponível.

# %% [markdown]
# ## Atividade 2
#
# 2. [ ] Garanta que features sejam criadas respeitando tempo.

# %% [markdown]
# ## Atividade 3
#
# 3. [ ] Faça backtesting com múltiplos cortes.

# %% [markdown]
# ## Atividade 4
#
# 4. [ ] Compare erro e estabilidade por horizonte.

# %% [markdown]
# ## Atividade 5
#
# 5. [ ] Analise resíduos e autocorrelação remanescente.

# %% [markdown]
# ## Exercícios Extras Específicos — 1
#
# 1. [ ] Adicione um quarto corte ao backtesting e compare a estabilidade de Random Forest e Holt-Winters.

# %% [markdown]
# ## Exercícios Extras Específicos — 2
#
# 2. [ ] Meça autocorrelação dos resíduos nos lags 1 e 7 e registre qual padrão ainda não foi capturado.
