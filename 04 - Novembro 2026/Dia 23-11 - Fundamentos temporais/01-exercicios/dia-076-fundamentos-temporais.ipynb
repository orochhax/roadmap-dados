# %% [markdown]
# # Dia 076 — Fundamentos temporais
#
# **Data:** 16/11/2026
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. [ ] Carregue `energia.csv`, converta índice temporal e verifique frequência, lacunas e duplicidades.

# %% [markdown]
# ## Atividade 2
#
# 2. [ ] Separe tendência, sazonalidade e ruído por gráficos e médias móveis.

# %% [markdown]
# ## Atividade 3
#
# 3. [ ] Calcule autocorrelação em atrasos 1, 7 e 30.

# %% [markdown]
# ## Atividade 4
#
# 4. [ ] Crie features de calendário e lags sem olhar o futuro.

# %% [markdown]
# ## Atividade 5
#
# 5. [ ] Defina horizonte de previsão e decisão operacional associada.

# %% [markdown]
# ## Exercícios Extras Específicos — 1
#
# 1. [ ] Remova sete dias consecutivos de uma cópia da série e mostre como a verificação de frequência identifica a lacuna.

# %% [markdown]
# ## Exercícios Extras Específicos — 2
#
# 2. [ ] Crie lags 1, 7 e 30 e confirme que cada linha usa somente datas anteriores à própria data.
