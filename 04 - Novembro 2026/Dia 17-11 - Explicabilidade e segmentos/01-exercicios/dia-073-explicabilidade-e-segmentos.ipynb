# %% [markdown]
# # Dia 073 — Explicabilidade e segmentos
#
# **Data:** 11/11/2026
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. [ ] Produza importância global e explicações individuais para 12 clientes.

# %% [markdown]
# ## Atividade 2
#
# 2. [ ] Crie segmentos acionáveis combinando risco, valor e motivo provável.

# %% [markdown]
# ## Atividade 3
#
# 3. [ ] Verifique desempenho por cidade e plano.

# %% [markdown]
# ## Atividade 4
#
# 4. [ ] Identifique possíveis vieses e grupos com baixo suporte.

# %% [markdown]
# ## Atividade 5
#
# 5. [ ] Escreva exemplos de mensagens operacionais para o time de retenção sem expor informações sensíveis.

# %% [markdown]
# ## Exercícios Extras Específicos — 1
#
# 1. [ ] Explique três clientes de alto risco e alto valor e três de alto risco e baixo valor com o mesmo método.

# %% [markdown]
# ## Exercícios Extras Específicos — 2
#
# 2. [ ] Compare recall e precision entre Salvador e Feira de Santana e informe o número de casos em cada cidade.
