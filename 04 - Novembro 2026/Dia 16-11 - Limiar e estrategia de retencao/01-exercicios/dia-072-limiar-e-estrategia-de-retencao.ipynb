# %% [markdown]
# # Dia 072 — Limiar e estratégia de retenção
#
# **Data:** 10/11/2026
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. [ ] Calcule custo e volume de campanhas para 20 limiares entre 0.05 e 0.95.

# %% [markdown]
# ## Atividade 2
#
# 2. [ ] Defina três estratégias de retenção por risco e valor do cliente.

# %% [markdown]
# ## Atividade 3
#
# 3. [ ] Simule orçamento limitado e selecione os clientes com maior benefício esperado.

# %% [markdown]
# ## Atividade 4
#
# 4. [ ] Calcule retorno estimado e ponto de equilíbrio.

# %% [markdown]
# ## Atividade 5
#
# 5. [ ] Crie regras de exclusão para evitar ofertas inadequadas.

# %% [markdown]
# ## Exercícios Extras Específicos — 1
#
# 1. [ ] Simule orçamento suficiente para abordar somente 100 clientes e selecione pelo maior benefício esperado.

# %% [markdown]
# ## Exercícios Extras Específicos — 2
#
# 2. [ ] Aumente o custo da campanha em 50% e recalcule retorno e ponto de equilíbrio sem alterar probabilidades.
