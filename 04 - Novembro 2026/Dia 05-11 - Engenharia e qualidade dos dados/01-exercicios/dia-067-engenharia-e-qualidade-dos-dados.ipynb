# %% [markdown]
# # Dia 067 — Engenharia e qualidade dos dados
#
# **Data:** 03/11/2026
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. [ ] Carregue `clientes_telecom.csv`, valide esquema e gere relatório de qualidade por coluna.

# %% [markdown]
# ## Atividade 2
#
# 2. [ ] Defina regras de negócio para ausentes, duplicados, NPS fora de 0–10, mensalidade negativa e datas inconsistentes.

# %% [markdown]
# ## Atividade 3
#
# 3. [ ] Implemente função de validação que falhe com mensagens claras.

# %% [markdown]
# ## Atividade 4
#
# 4. [ ] Crie base analítica limpa e dicionário de dados.

# %% [markdown]
# ## Atividade 5
#
# 5. [ ] Registre quantidade de linhas alteradas ou removidas e impacto na taxa de churn.

# %% [markdown]
# ## Exercícios Extras Específicos — 1
#
# 1. [ ] Crie uma linha com NPS=11 e outra com mensalidade=-1 e faça a validação listar os dois erros separadamente.

# %% [markdown]
# ## Exercícios Extras Específicos — 2
#
# 2. [ ] Compare a taxa de churn antes e depois de remover somente registros realmente inválidos e registre quantas linhas mudaram.
