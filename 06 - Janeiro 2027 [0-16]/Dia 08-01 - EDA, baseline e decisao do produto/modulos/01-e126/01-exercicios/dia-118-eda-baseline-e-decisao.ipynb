# %% [markdown]
# ## Começo guiado
#
# **Dados de partida:** `product_brief.md`, dataset validado, corte e métrica; use uma amostra determinística como fallback local.
#
# Não crie uma base nova. Use os valores, arquivos ou tabelas já indicados e resolva uma atividade por vez. Execute a célula e confira o número, a tabela ou o gráfico antes de seguir.

# %% [markdown]
# # EDA, baseline e decisão
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. [ ] Faça EDA focada nas hipóteses do produto.

# %% [markdown]
# ## Atividade 2
#
# 2. [ ] Implemente baseline de negócio e técnico.

# %% [markdown]
# ## Atividade 3
#
# 3. [ ] Defina limiar/regra de decisão.

# %% [markdown]
# ## Prática obrigatória — sensibilidade
#
# 4. [ ] Refaça a decisão aumentando o custo do pior erro em 50% e registre se limiar ou ação recomendada muda.

# %% [markdown]
# ## Prática obrigatória — decisão
#
# 5. [ ] Produza um memorando de uma página com impacto esperado, pior cenário, decisão e limitação.

# %% [markdown]
# ## Evidência da sensibilidade
#
# Registre o valor anterior, o novo valor e a mudança ou manutenção da decisão.

# %% [markdown]
# ## Limitação observada
#
# Registre uma limitação concreta da estimativa de impacto.
