# %% [markdown]
# ## Começo guiado
#
# **Dados de partida:** `product_brief.md`, fonte escolhida e schema; use DuckDB e fixtures válida, nula e duplicada como fallback local.
#
# Não crie uma base nova. Use os valores, arquivos ou tabelas já indicados e resolva uma atividade por vez. Execute a célula e confira o número, a tabela ou o gráfico antes de seguir.

# %% [markdown]
# # Dados, SQL e arquitetura
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. [ ] Crie ou revise esquema SQL e pipeline de formação da base.

# %% [markdown]
# ## Atividade 2
#
# 2. [ ] Adicione testes de qualidade e dicionário.

# %% [markdown]
# ## Atividade 3
#
# 3. [ ] Desenhe arquitetura de execução e deploy.

# %% [markdown]
# ## Prática obrigatória — validação
#
# 4. [ ] Remova cliente_id de uma cópia da entrada e faça a checagem de qualidade impedir a formação da base.

# %% [markdown]
# ## Prática obrigatória — reprodução
#
# 5. [ ] Documente uma única instrução de reprodução, execute-a duas vezes e confirme que a segunda execução não duplica linhas nem artefatos.

# %% [markdown]
# ## Evidência da validação
#
# Registre entrada, resultado esperado e resultado observado no teste sem cliente_id.

# %% [markdown]
# ## Limitação e privacidade
#
# Registre uma limitação de reprodução e um cuidado de privacidade aplicável aos dados.
