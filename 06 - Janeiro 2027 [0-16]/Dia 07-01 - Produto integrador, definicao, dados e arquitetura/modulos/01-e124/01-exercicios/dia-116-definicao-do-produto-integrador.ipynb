# %% [markdown]
# ## Começo guiado
#
# **Dados de partida:** escolha `dados/clientes_telecom.csv`, `dados/pedidos.csv` ou `projetos/assistente-suporte-ia/data/corpus/`; use uma fixture versionada como fallback local.
#
# Não crie uma base nova. Use os valores, arquivos ou tabelas já indicados e resolva uma atividade por vez. Execute a célula e confira o número, a tabela ou o gráfico antes de seguir.

# %% [markdown]
# # Definição do produto integrador
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. [ ] Escolha um produto integrador entre churn, crédito, forecasting ou RAG e defina usuário, decisão e valor.

# %% [markdown]
# ## Atividade 2
#
# 2. [ ] Escreva escopo de cinco dias com backlog priorizado MoSCoW.

# %% [markdown]
# ## Atividade 3
#
# 3. [ ] Desenhe arquitetura e fluxo de dados.

# %% [markdown]
# ## Prática obrigatória — métricas
#
# 4. [ ] Defina métricas técnicas, de negócio e de experiência.

# %% [markdown]
# ## Prática obrigatória — escopo sob restrição
#
# 5. [ ] Acrescente um caso de usuário com entrada incompleta ao backlog; depois reduza o prazo de cinco para três dias e registre dois cortes que preservam o valor principal.

# %% [markdown]
# ## Evidência da prática
#
# Registre a classificação MoSCoW do caso incompleto e justifique os dois cortes.

# %% [markdown]
# ## Limitação observada
#
# Registre uma limitação concreta que permaneceu no escopo de três dias.
