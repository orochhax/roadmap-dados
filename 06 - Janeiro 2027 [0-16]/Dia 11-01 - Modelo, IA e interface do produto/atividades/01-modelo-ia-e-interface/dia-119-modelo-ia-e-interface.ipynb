# %% [markdown]
# ## Começo guiado
#
# **Dados de partida:** contrato e artefato local do componente; use modelo, regra ou mock sem serviço externo como fallback local.
#
# Não crie uma base nova. Use os valores, arquivos ou tabelas já indicados e resolva uma atividade por vez. Execute a célula e confira o número, a tabela ou o gráfico antes de seguir.

# %% [markdown]
# # Modelo, IA e interface
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. Integre o componente definido no produto. Se for RAG, valide as 15 linhas e hashes de `projetos/assistente-suporte-ia/data/corpus/corpus_manifest.csv` e as dez perguntas correspondentes em `projetos/assistente-suporte-ia/outputs/avaliacao/avaliacao_rag.csv`.

# %% [markdown]
# ## Atividade 2
#
# 2. Crie uma interface mínima entre API, dashboard ou aplicação simples; escolha apenas uma.

# %% [markdown]
# ## Atividade 3
#
# 3. Teste o fluxo ponta a ponta com oito casos variados.

# %% [markdown]
# ## Atividade 4
#
# 4. Registre métrica principal, latência aproximada, custo e duas falhas conhecidas.

# %% [markdown]
# ## Prática obrigatória — entrada inválida
#
# 5. Inclua um caso com campos ausentes nos oito testes ponta a ponta e faça a interface explicar o que precisa ser corrigido.

# %% [markdown]
# ## Prática obrigatória — latência
#
# 6. Simule latência de 2 segundos no componente principal e registre a experiência da interface e o timeout escolhido.

# %% [markdown]
# ## Evidência dos testes
#
# Registre resultado esperado e observado para a entrada inválida e para a latência simulada.
