# %% [markdown]
# ## Começo guiado
#
# **Dados de partida:** `dados/clientes_telecom.csv`, `dados/incidentes.csv` e dados sintéticos gerados no notebook com seed 42.
#
# Não crie uma base nova. Use os valores, arquivos ou tabelas já indicados e resolva uma atividade por vez. Execute a célula e confira o número, a tabela ou o gráfico antes de seguir.

# %% [markdown]
# # Intervalos de confiança
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. Calcule um intervalo de confiança de 95% para a média manualmente e com biblioteca, declarando as suposições usadas.

# %% [markdown]
# ## Atividade 2
#
# 2. Compare a largura do intervalo de 95% em amostras de tamanho 20 e 100.

# %% [markdown]
# ## Atividade 3
#
# 3. Escreva a interpretação correta do intervalo sem atribuir probabilidade ao parâmetro fixo.

# %% [markdown]
# ## Prática obrigatória 1
#
# 4. Compare intervalos de 90%, 95% e 99% e explique o efeito do nível de confiança na largura.

# %% [markdown]
# ## Prática obrigatória 2
#
# 5. Calcule o IC de 95% para as primeiras 50 durações por método paramétrico e bootstrap com seed 42; compare as larguras.
#
# 6. Repita com a amostra constante [60, 60, 60, 60, 60] e trate explicitamente a ausência de variabilidade.
