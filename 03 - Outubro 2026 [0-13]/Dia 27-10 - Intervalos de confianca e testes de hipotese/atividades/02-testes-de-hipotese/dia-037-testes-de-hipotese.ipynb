# %% [markdown]
# ## Começo guiado
#
# **Dados de partida:** `dados/clientes_telecom.csv`, `dados/incidentes.csv` e dados sintéticos gerados no notebook com seed 42.
#
# Não crie uma base nova. Use os valores, arquivos ou tabelas já indicados e resolva uma atividade por vez. Execute a célula e confira o número, a tabela ou o gráfico antes de seguir.

# %% [markdown]
# # Testes de hipótese
#
# > Notebook preparado somente com os enunciados. Nenhuma atividade foi resolvida.

# %% [markdown]
# ## Atividade 1
#
# 1. Formule H0 e H1 para diferença de média de duração entre duas cidades.

# %% [markdown]
# ## Atividade 2
#
# 2. Escolha e execute teste apropriado; verifique suposições e calcule tamanho de efeito.

# %% [markdown]
# ## Atividade 3
#
# 3. Resolva um teste de proporções para taxa de churn entre dois planos.

# %% [markdown]
# ## Prática obrigatória 1
#
# 4. Crie cenários de erro tipo I e II com consequências de negócio.

# %% [markdown]
# ## Prática obrigatória 2
#
# 5. Escreva decisão usando significância, efeito, intervalo e custo, sem depender só de p-valor.
#
# 6. Acrescente um outlier de 1500 minutos a uma cidade, refaça suposições e tamanho de efeito e compare com a análise original.
